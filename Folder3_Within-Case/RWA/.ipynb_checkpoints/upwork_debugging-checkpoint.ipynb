# %%
# Setting parameters, replace with defaults when using a master notebook

countrycode = 'RWA'
countryname = 'Rwanda'

print("Parameters set")
# Out:
# Parameters set

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.transform import from_origin
from rasterstats import zonal_stats
import numpy as np
import os
import time
from rasterio.features import geometry_mask
from rasterio.mask import mask
from osgeo import gdal
gdal.UseExceptions()
from exactextract import exact_extract
import matplotlib.pyplot as plt
from shapely.geometry import shape
from shapely.ops import unary_union
import statsmodels.api as sm
import pyreadr

print("All done.")
# Out:
# All done.

# %% [markdown]
# # Load and Prepare Data

# %%
start_time = time.time()

# Load the rds data
rds_file = countrycode + '_ntl_pop.rds'
results = pyreadr.read_r(rds_file)
# Extract the data frame from the result
data = results[None]  # Extracts the first (and usually only) dataframe from the result


print("Data loaded")

# Debugging: Check the first few rows of the data
print("Data preview before 'haslight' column creation:")
print(data.head(100))

# Create a binary 'haslight' column based on 'ntl' values
data['haslight'] = (data['ntl'] > 0).astype(int)

# Debugging: Check the first few rows after 'haslight' column creation
print("Data preview after 'haslight' column creation:")
print(data.head(100))

data.drop(columns=['ntl', 'pop'], inplace=True)
print("Columns 'ntl' and 'pop' dropped")
# Out:
# Data loaded
# Data preview before 'haslight' column creation:
#             x         y  ntl         pop
# 0   30.447917 -1.047917  0.0   18.384934
# 1   30.439583 -1.052083  0.0  134.318776
# 2   30.443750 -1.052083  0.0  182.569638
# 3   30.447917 -1.052083  0.0   73.298034
# 4   30.452083 -1.052083  0.0   15.015528
# ..        ...       ...  ...         ...
# 95  30.460417 -1.072917  0.0    0.000000
# 96  30.352083 -1.077083  0.0    1.436540
# 97  30.356250 -1.077083  0.0    0.000000
# 98  30.360417 -1.077083  0.0   65.475285
# 99  30.364583 -1.077083  0.0   87.764640
#
# [100 rows x 4 columns]
# Data preview after 'haslight' column creation:
#             x         y  ntl         pop  haslight
# 0   30.447917 -1.047917  0.0   18.384934         0
# 1   30.439583 -1.052083  0.0  134.318776         0
# 2   30.443750 -1.052083  0.0  182.569638         0
# 3   30.447917 -1.052083  0.0   73.298034         0
# 4   30.452083 -1.052083  0.0   15.015528         0
# ..        ...       ...  ...         ...       ...
# 95  30.460417 -1.072917  0.0    0.000000         0
# 96  30.352083 -1.077083  0.0    1.436540         0
# 97  30.356250 -1.077083  0.0    0.000000         0
# 98  30.360417 -1.077083  0.0   65.475285         0
# 99  30.364583 -1.077083  0.0   87.764640         0
#
# [100 rows x 5 columns]
# Columns 'ntl' and 'pop' dropped

# %% [markdown]
# # Convert DataFrame to GeoDataFrame
#
# Fast

# %%
start_time = time.time()
# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data['x'], data['y']))
print("Converted to GeoDataFrame")
end_time = time.time()
print(f"Time to execute: {((time.time() - start_time)/60):.2f}")
# Out:
# Converted to GeoDataFrame
# Time to execute: 0.00

# %% [markdown]
# # Create and Initialize Raster
#
# Fast

# %%
start_time = time.time()

#convert arc seconds to decimal degrees (to determine pixel size)
pixel_size = 15 / 3600 

#Retrieve the minimum and maximum x (longitude) and y (latitude) bounds to determine geographical extent of data
xmin, ymin, xmax, ymax = gdf.total_bounds

#Calcuate width and heigth of raster based on min max values
width = int(np.ceil((xmax - xmin) / pixel_size))
height = int(np.ceil((ymax - ymin) / pixel_size))

#define affine transformation parameters (linear mapping method)
transform = from_origin(xmin, ymax, pixel_size, pixel_size)

#prepare raster meta data
raster_meta = {
    'driver': 'GTiff',
    'count': 1,
    'dtype': 'int32',
    'width': width,
    'height': height,
    'crs': 'EPSG:4326',
    'transform': transform,
    'nodata': -999  # Explicitly setting nodata value
}
print("Raster metadata prepared")

# Initialize raster (create an empty raster with the specified dimensions and data type)
with rasterio.open('haslight.tif', 'w+', **raster_meta) as raster_data:
    raster_data.write_band(1, np.zeros((height, width), dtype='int32'))
    print("Raster initialized")

print(f"Time to execute: {((time.time() - start_time)/60):.2f}")
# Out:
# Raster metadata prepared
# Raster initialized
# Time to execute: 0.00

# %% [markdown]
# # Burn 'haslight' Values into Raster
#
# Fast

# %%
start_time = time.time()
gdf.crs = "EPSG:4326" 

if gdf.crs != raster_data.crs:
    gdf = gdf.to_crs(raster_data.crs)
    print("CRS of gdf matched to raster data")
    
# Burn 'haslight' Values into Raster
with rasterio.open('haslight.tif', 'r+') as raster_data:
    # Prepare to burn the 'haslight' values into the raster
    row_indices = np.floor((ymax - gdf['geometry'].y) / pixel_size).astype(int)
    col_indices = np.floor((gdf['geometry'].x - xmin) / pixel_size).astype(int)
    
    # Check if any indices are out of bounds
    valid_rows = (row_indices >= 0) & (row_indices < raster_data.height)
    valid_cols = (col_indices >= 0) & (col_indices < raster_data.width)
    valid = valid_rows & valid_cols

    # Calculate number and proportion of out-of-bounds coordinates
    num_out_of_bounds = len(gdf) - valid.sum()
    proportion_out_of_bounds = num_out_of_bounds / len(gdf)

    if not valid.all():
        print("Warning: Some points are out of bounds and will not be included in the raster.")

    # Create a full array of the raster
    raster_array = raster_data.read(1)
    
    # Update raster values based on 'haslight' column
    for i in range(len(gdf)):
        if valid[i]:
            raster_array[row_indices[i], col_indices[i]] = gdf['haslight'].iloc[i]
    
    # Write the updated raster array back to the file
    raster_data.write_band(1, raster_array)

print("Haslight values burnt into the raster")
print(f"Total time to execute: {((time.time() - start_time)/60):.2f} minutes")

# Print overview of out-of-bounds coordinates
print(f"Number of coordinates that fell outside of the raster: {num_out_of_bounds}")
print(f"Proportion of coordinates that fell outside of the raster: {proportion_out_of_bounds:.2%}")
# Out:
# Haslight values burnt into the raster
# Total time to execute: 0.04 minutes
# Number of coordinates that fell outside of the raster: 0
# Proportion of coordinates that fell outside of the raster: 0.00%

# %% [markdown]
# ### Robustness check 1: check if value in haslight raster matches original values

# %%
# Debugging
raster_path = 'haslight.tif'
with rasterio.open(raster_path) as src:
    raster_data = src.read(1)
    transform = src.transform

    # Ensure CRS match
    if gdf.crs != src.crs:
        gdf = gdf.to_crs(src.crs)
        print("CRS updated")

    # Calculate row and column indices
    coords = [(geom.x, geom.y) for geom in gdf['geometry']]
    row_indices, col_indices = zip(*[~src.transform * coord for coord in coords])
    row_indices = np.floor(row_indices).astype(int)
    col_indices = np.floor(col_indices).astype(int)

    # Validate values
    mismatches = []
    for i in range(len(gdf)):
        if 0 <= row_indices[i] < src.height and 0 <= col_indices[i] < src.width:
            raster_value = raster_data[row_indices[i], col_indices[i]]
            original_value = gdf['haslight'].iloc[i]
            if raster_value != original_value:
                mismatches.append((i, raster_value, original_value))

    if mismatches:
        print(f"Found {len(mismatches)} mismatches out of {len(gdf)} total points")
        for idx, raster_val, orig_val in mismatches:
            print(f"Mismatch at index {idx}: Raster value = {raster_val}, Original value = {orig_val}")
    else:
        print("All values match")
# Out:
# Found 7515 mismatches out of 118346 total points
# Mismatch at index 5: Raster value = 0, Original value = 1
# Mismatch at index 10: Raster value = 0, Original value = 1
# Mismatch at index 11: Raster value = 0, Original value = 1
# Mismatch at index 12: Raster value = 0, Original value = 1
# Mismatch at index 21: Raster value = 0, Original value = 1
# Mismatch at index 69: Raster value = 1, Original value = 0
# Mismatch at index 70: Raster value = 1, Original value = 0
# Mismatch at index 96: Raster value = 1, Original value = 0
# Mismatch at index 122: Raster value = 1, Original value = 0
# Mismatch at index 355: Raster value = 0, Original value = 1
# Mismatch at index 382: Raster value = 0, Original value = 1
# Mismatch at index 383: Raster value = 0, Original value = 1
# Mismatch at index 1066: Raster value = 1, Original value = 0
# Mismatch at index 1119: Raster value = 1, Original value = 0
# Mismatch at index 1173: Raster value = 1, Original value = 0
# Mismatch at index 1208: Raster value = 1, Original value = 0
# Mismatch at index 1266: Raster value = 1, Original value = 0
# Mismatch at index 1324: Raster value = 1, Original value = 0
# Mismatch at index 1474: Raster value = 1, Original value = 0
# Mismatch at index 1475: Raster value = 1, Original value = 0
# Mismatch at index 1540: Raster value = 1, Original value = 0
# Mismatch at index 1541: Raster value = 1, Original value = 0
# Mismatch at index 1606: Raster value = 1, Original value = 0
# Mismatch at index 1608: Raster value = 1, Original value = 0
# Mismatch at index 1609: Raster value = 1, Original value = 0
# Mismatch at index 1674: Raster value = 1, Original value = 0
# Mismatch at index 1675: Raster value = 1, Original value = 0
# Mismatch at index 1677: Raster value = 1, Original value = 0
# Mismatch at index 1678: Raster value = 1, Original value = 0
# Mismatch at index 1743: Raster value = 1, Original value = 0
# Mismatch at index 1744: Raster value = 1, Original value = 0
# Mismatch at index 1814: Raster value = 1, Original value = 0
# Mismatch at index 1886: Raster value = 1, Original value = 0
# Mismatch at index 1958: Raster value = 1, Original value = 0
# Mismatch at index 2034: Raster value = 1, Original value = 0
# Mismatch at index 2112: Raster value = 1, Original value = 0
# Mismatch at index 2191: Raster value = 1, Original value = 0
# Mismatch at index 2194: Raster value = 1, Original value = 0
# Mismatch at index 2270: Raster value = 1, Original value = 0
# Mismatch at index 2273: Raster value = 1, Original value = 0
# Mismatch at index 2352: Raster value = 1, Original value = 0
# Mismatch at index 2355: Raster value = 1, Original value = 0
# Mismatch at index 2356: Raster value = 1, Original value = 0
# Mismatch at index 2427: Raster value = 1, Original value = 0
# Mismatch at index 2436: Raster value = 1, Original value = 0
# Mismatch at index 2439: Raster value = 1, Original value = 0
# Mismatch at index 2440: Raster value = 1, Original value = 0
# Mismatch at index 2441: Raster value = 1, Original value = 0
# Mismatch at index 2443: Raster value = 1, Original value = 0
# Mismatch at index 2444: Raster value = 1, Original value = 0
# Mismatch at index 2445: Raster value = 1, Original value = 0
# Mismatch at index 2513: Raster value = 1, Original value = 0
# Mismatch at index 2531: Raster value = 1, Original value = 0
# Mismatch at index 2532: Raster value = 1, Original value = 0
# Mismatch at index 2534: Raster value = 1, Original value = 0
# Mismatch at index 2535: Raster value = 1, Original value = 0
# Mismatch at index 2536: Raster value = 1, Original value = 0
# Mismatch at index 2549: Raster value = 0, Original value = 1
# Mismatch at index 2628: Raster value = 1, Original value = 0
# Mismatch at index 2629: Raster value = 1, Original value = 0
# Mismatch at index 2640: Raster value = 0, Original value = 1
# Mismatch at index 2641: Raster value = 0, Original value = 1
# Mismatch at index 2642: Raster value = 0, Original value = 1
# Mismatch at index 2643: Raster value = 0, Original value = 1
# Mismatch at index 2644: Raster value = 0, Original value = 1
# Mismatch at index 2721: Raster value = 1, Original value = 0
# Mismatch at index 2722: Raster value = 1, Original value = 0
# Mismatch at index 2733: Raster value = 0, Original value = 1
# Mismatch at index 2734: Raster value = 0, Original value = 1
# Mismatch at index 2735: Raster value = 0, Original value = 1
# Mismatch at index 2736: Raster value = 0, Original value = 1
# Mismatch at index 2737: Raster value = 0, Original value = 1
# Mismatch at index 2815: Raster value = 1, Original value = 0
# Mismatch at index 2816: Raster value = 1, Original value = 0
# Mismatch at index 2821: Raster value = 0, Original value = 1
# Mismatch at index 2822: Raster value = 0, Original value = 1
# Mismatch at index 2823: Raster value = 0, Original value = 1
# Mismatch at index 2824: Raster value = 0, Original value = 1
# Mismatch at index 2825: Raster value = 0, Original value = 1
# Mismatch at index 2826: Raster value = 0, Original value = 1
# Mismatch at index 2827: Raster value = 0, Original value = 1
# Mismatch at index 2828: Raster value = 0, Original value = 1
# Mismatch at index 2829: Raster value = 0, Original value = 1
# Mismatch at index 2830: Raster value = 0, Original value = 1
# Mismatch at index 2831: Raster value = 0, Original value = 1
# Mismatch at index 2914: Raster value = 0, Original value = 1
# Mismatch at index 2915: Raster value = 0, Original value = 1
# Mismatch at index 2916: Raster value = 0, Original value = 1
# Mismatch at index 2917: Raster value = 0, Original value = 1
# Mismatch at index 2918: Raster value = 0, Original value = 1
# Mismatch at index 2919: Raster value = 0, Original value = 1
# Mismatch at index 2920: Raster value = 0, Original value = 1
# Mismatch at index 2921: Raster value = 0, Original value = 1
# Mismatch at index 2922: Raster value = 0, Original value = 1
# Mismatch at index 2923: Raster value = 0, Original value = 1
# Mismatch at index 3002: Raster value = 1, Original value = 0
# Mismatch at index 3003: Raster value = 1, Original value = 0
# Mismatch at index 3007: Raster value = 0, Original value = 1
# Mismatch at index 3008: Raster value = 0, Original value = 1
# Mismatch at index 3009: Raster value = 0, Original value = 1
# Mismatch at index 3010: Raster value = 0, Original value = 1
# Mismatch at index 3011: Raster value = 0, Original value = 1
# Mismatch at index 3012: Raster value = 0, Original value = 1
# Mismatch at index 3013: Raster value = 0, Original value = 1
# Mismatch at index 3014: Raster value = 0, Original value = 1
# Mismatch at index 3015: Raster value = 0, Original value = 1
# Mismatch at index 3071: Raster value = 0, Original value = 1
# Mismatch at index 3094: Raster value = 1, Original value = 0
# Mismatch at index 3095: Raster value = 1, Original value = 0
# Mismatch at index 3101: Raster value = 0, Original value = 1
# Mismatch at index 3102: Raster value = 0, Original value = 1
# Mismatch at index 3103: Raster value = 0, Original value = 1
# Mismatch at index 3104: Raster value = 0, Original value = 1
# Mismatch at index 3105: Raster value = 0, Original value = 1
# Mismatch at index 3106: Raster value = 0, Original value = 1
# Mismatch at index 3188: Raster value = 1, Original value = 0
# Mismatch at index 3190: Raster value = 1, Original value = 0
# Mismatch at index 3194: Raster value = 0, Original value = 1
# Mismatch at index 3195: Raster value = 0, Original value = 1
# Mismatch at index 3196: Raster value = 0, Original value = 1
# Mismatch at index 3197: Raster value = 0, Original value = 1
# Mismatch at index 3198: Raster value = 0, Original value = 1
# Mismatch at index 3282: Raster value = 1, Original value = 0
# Mismatch at index 3284: Raster value = 1, Original value = 0
# Mismatch at index 3288: Raster value = 0, Original value = 1
# Mismatch at index 3289: Raster value = 0, Original value = 1
# Mismatch at index 3290: Raster value = 0, Original value = 1
# Mismatch at index 3291: Raster value = 0, Original value = 1
# Mismatch at index 3380: Raster value = 1, Original value = 0
# Mismatch at index 3384: Raster value = 0, Original value = 1
# Mismatch at index 3385: Raster value = 0, Original value = 1
# Mismatch at index 3386: Raster value = 0, Original value = 1
# Mismatch at index 3387: Raster value = 0, Original value = 1
# Mismatch at index 3479: Raster value = 1, Original value = 0
# Mismatch at index 3480: Raster value = 0, Original value = 1
# Mismatch at index 3483: Raster value = 0, Original value = 1
# Mismatch at index 3484: Raster value = 0, Original value = 1
# Mismatch at index 3485: Raster value = 0, Original value = 1
# Mismatch at index 3581: Raster value = 0, Original value = 1
# Mismatch at index 3583: Raster value = 1, Original value = 0
# Mismatch at index 3680: Raster value = 1, Original value = 0
# Mismatch at index 3683: Raster value = 1, Original value = 0
# Mismatch at index 3785: Raster value = 1, Original value = 0
# Mismatch at index 3788: Raster value = 1, Original value = 0
# Mismatch at index 3891: Raster value = 1, Original value = 0
# Mismatch at index 3894: Raster value = 1, Original value = 0
# Mismatch at index 3998: Raster value = 1, Original value = 0
# Mismatch at index 4001: Raster value = 1, Original value = 0
# Mismatch at index 4070: Raster value = 0, Original value = 1
# Mismatch at index 4071: Raster value = 0, Original value = 1
# Mismatch at index 4116: Raster value = 1, Original value = 0
# Mismatch at index 4238: Raster value = 1, Original value = 0
# Mismatch at index 4240: Raster value = 1, Original value = 0
# Mismatch at index 4678: Raster value = 1, Original value = 0
# Mismatch at index 4689: Raster value = 0, Original value = 1
# Mismatch at index 4690: Raster value = 0, Original value = 1
# Mismatch at index 4826: Raster value = 0, Original value = 1
# Mismatch at index 4827: Raster value = 0, Original value = 1
# Mismatch at index 4836: Raster value = 1, Original value = 0
# Mismatch at index 4847: Raster value = 0, Original value = 1
# Mismatch at index 4990: Raster value = 0, Original value = 1
# Mismatch at index 4991: Raster value = 0, Original value = 1
# Mismatch at index 5002: Raster value = 1, Original value = 0
# Mismatch at index 5020: Raster value = 0, Original value = 1
# Mismatch at index 5154: Raster value = 0, Original value = 1
# Mismatch at index 5155: Raster value = 0, Original value = 1
# Mismatch at index 5156: Raster value = 0, Original value = 1
# Mismatch at index 5157: Raster value = 0, Original value = 1
# Mismatch at index 5167: Raster value = 1, Original value = 0
# Mismatch at index 5170: Raster value = 1, Original value = 0
# Mismatch at index 5185: Raster value = 0, Original value = 1
# Mismatch at index 5327: Raster value = 0, Original value = 1
# Mismatch at index 5328: Raster value = 0, Original value = 1
# Mismatch at index 5329: Raster value = 0, Original value = 1
# Mismatch at index 5330: Raster value = 0, Original value = 1
# Mismatch at index 5331: Raster value = 0, Original value = 1
# Mismatch at index 5339: Raster value = 1, Original value = 0
# Mismatch at index 5341: Raster value = 1, Original value = 0
# Mismatch at index 5344: Raster value = 1, Original value = 0
# Mismatch at index 5506: Raster value = 0, Original value = 1
# Mismatch at index 5507: Raster value = 0, Original value = 1
# Mismatch at index 5508: Raster value = 0, Original value = 1
# Mismatch at index 5509: Raster value = 0, Original value = 1
# Mismatch at index 5518: Raster value = 1, Original value = 0
# Mismatch at index 5520: Raster value = 1, Original value = 0
# Mismatch at index 5523: Raster value = 1, Original value = 0
# Mismatch at index 5702: Raster value = 1, Original value = 0
# Mismatch at index 5703: Raster value = 1, Original value = 0
# Mismatch at index 5704: Raster value = 1, Original value = 0
# Mismatch at index 5706: Raster value = 1, Original value = 0
# Mismatch at index 5728: Raster value = 1, Original value = 0
# Mismatch at index 5729: Raster value = 1, Original value = 0
# Mismatch at index 5730: Raster value = 1, Original value = 0
# Mismatch at index 5731: Raster value = 1, Original value = 0
# Mismatch at index 5911: Raster value = 1, Original value = 0
# Mismatch at index 5912: Raster value = 1, Original value = 0
# Mismatch at index 5913: Raster value = 1, Original value = 0
# Mismatch at index 5937: Raster value = 1, Original value = 0
# Mismatch at index 5940: Raster value = 1, Original value = 0
# Mismatch at index 6129: Raster value = 1, Original value = 0
# Mismatch at index 6130: Raster value = 1, Original value = 0
# Mismatch at index 6152: Raster value = 1, Original value = 0
# Mismatch at index 6154: Raster value = 1, Original value = 0
# Mismatch at index 6157: Raster value = 1, Original value = 0
# Mismatch at index 6158: Raster value = 1, Original value = 0
# Mismatch at index 6159: Raster value = 1, Original value = 0
# Mismatch at index 6160: Raster value = 1, Original value = 0
# Mismatch at index 6352: Raster value = 1, Original value = 0
# Mismatch at index 6353: Raster value = 1, Original value = 0
# Mismatch at index 6375: Raster value = 1, Original value = 0
# Mismatch at index 6377: Raster value = 1, Original value = 0
# Mismatch at index 6380: Raster value = 1, Original value = 0
# Mismatch at index 6381: Raster value = 1, Original value = 0
# Mismatch at index 6382: Raster value = 1, Original value = 0
# Mismatch at index 6383: Raster value = 1, Original value = 0
# Mismatch at index 6385: Raster value = 1, Original value = 0
# Mismatch at index 6388: Raster value = 1, Original value = 0
# Mismatch at index 6389: Raster value = 1, Original value = 0
# Mismatch at index 6579: Raster value = 1, Original value = 0
# Mismatch at index 6580: Raster value = 1, Original value = 0
# Mismatch at index 6602: Raster value = 1, Original value = 0
# Mismatch at index 6604: Raster value = 1, Original value = 0
# Mismatch at index 6609: Raster value = 1, Original value = 0
# Mismatch at index 6610: Raster value = 1, Original value = 0
# Mismatch at index 6612: Raster value = 1, Original value = 0
# Mismatch at index 6615: Raster value = 1, Original value = 0
# Mismatch at index 6616: Raster value = 1, Original value = 0
# Mismatch at index 6810: Raster value = 1, Original value = 0
# Mismatch at index 6811: Raster value = 1, Original value = 0
# Mismatch at index 6812: Raster value = 1, Original value = 0
# Mismatch at index 6834: Raster value = 1, Original value = 0
# Mismatch at index 6836: Raster value = 1, Original value = 0
# Mismatch at index 6847: Raster value = 1, Original value = 0
# Mismatch at index 6848: Raster value = 1, Original value = 0
# Mismatch at index 6981: Raster value = 0, Original value = 1
# Mismatch at index 6983: Raster value = 0, Original value = 1
# Mismatch at index 6984: Raster value = 0, Original value = 1
# Mismatch at index 7048: Raster value = 1, Original value = 0
# Mismatch at index 7049: Raster value = 1, Original value = 0
# Mismatch at index 7050: Raster value = 1, Original value = 0
# Mismatch at index 7052: Raster value = 1, Original value = 0
# Mismatch at index 7055: Raster value = 1, Original value = 0
# Mismatch at index 7056: Raster value = 1, Original value = 0
# Mismatch at index 7070: Raster value = 1, Original value = 0
# Mismatch at index 7071: Raster value = 1, Original value = 0
# Mismatch at index 7072: Raster value = 1, Original value = 0
# Mismatch at index 7074: Raster value = 1, Original value = 0
# Mismatch at index 7228: Raster value = 0, Original value = 1
# Mismatch at index 7421: Raster value = 0, Original value = 1
# Mismatch at index 7654: Raster value = 1, Original value = 0
# Mismatch at index 7655: Raster value = 1, Original value = 0
# Mismatch at index 7677: Raster value = 0, Original value = 1
# Mismatch at index 7678: Raster value = 0, Original value = 1
# Mismatch at index 7742: Raster value = 0, Original value = 1
# Mismatch at index 7803: Raster value = 1, Original value = 0
# Mismatch at index 7804: Raster value = 1, Original value = 0
# Mismatch at index 7805: Raster value = 1, Original value = 0
# Mismatch at index 7819: Raster value = 1, Original value = 0
# Mismatch at index 7820: Raster value = 1, Original value = 0
# Mismatch at index 7912: Raster value = 1, Original value = 0
# Mismatch at index 7913: Raster value = 1, Original value = 0
# Mismatch at index 8000: Raster value = 0, Original value = 1
# Mismatch at index 8001: Raster value = 0, Original value = 1
# Mismatch at index 8002: Raster value = 0, Original value = 1
# Mismatch at index 8063: Raster value = 1, Original value = 0
# Mismatch at index 8064: Raster value = 1, Original value = 0
# Mismatch at index 8065: Raster value = 1, Original value = 0
# Mismatch at index 8079: Raster value = 1, Original value = 0
# Mismatch at index 8080: Raster value = 1, Original value = 0
# Mismatch at index 8172: Raster value = 1, Original value = 0
# Mismatch at index 8173: Raster value = 1, Original value = 0
# Mismatch at index 8175: Raster value = 1, Original value = 0
# Mismatch at index 8176: Raster value = 1, Original value = 0
# Mismatch at index 8263: Raster value = 0, Original value = 1
# Mismatch at index 8264: Raster value = 0, Original value = 1
# Mismatch at index 8265: Raster value = 0, Original value = 1
# Mismatch at index 8298: Raster value = 1, Original value = 0
# Mismatch at index 8328: Raster value = 1, Original value = 0
# Mismatch at index 8329: Raster value = 1, Original value = 0
# Mismatch at index 8439: Raster value = 1, Original value = 0
# Mismatch at index 8440: Raster value = 1, Original value = 0
# Mismatch at index 8441: Raster value = 1, Original value = 0
# Mismatch at index 8442: Raster value = 1, Original value = 0
# Mismatch at index 8443: Raster value = 1, Original value = 0
# Mismatch at index 8600: Raster value = 1, Original value = 0
# Mismatch at index 8601: Raster value = 1, Original value = 0
# Mismatch at index 8710: Raster value = 1, Original value = 0
# Mismatch at index 8711: Raster value = 1, Original value = 0
# Mismatch at index 8712: Raster value = 1, Original value = 0
# Mismatch at index 8713: Raster value = 1, Original value = 0
# Mismatch at index 8714: Raster value = 1, Original value = 0
# Mismatch at index 8715: Raster value = 1, Original value = 0
# Mismatch at index 8726: Raster value = 0, Original value = 1
# Mismatch at index 8727: Raster value = 0, Original value = 1
# Mismatch at index 8871: Raster value = 1, Original value = 0
# Mismatch at index 8872: Raster value = 1, Original value = 0
# Mismatch at index 8874: Raster value = 1, Original value = 0
# Mismatch at index 8981: Raster value = 1, Original value = 0
# Mismatch at index 8983: Raster value = 1, Original value = 0
# Mismatch at index 8984: Raster value = 1, Original value = 0
# Mismatch at index 8985: Raster value = 1, Original value = 0
# Mismatch at index 8986: Raster value = 1, Original value = 0
# Mismatch at index 8987: Raster value = 1, Original value = 0
# Mismatch at index 8988: Raster value = 1, Original value = 0
# Mismatch at index 8998: Raster value = 0, Original value = 1
# Mismatch at index 8999: Raster value = 0, Original value = 1
# Mismatch at index 9000: Raster value = 0, Original value = 1
# Mismatch at index 9001: Raster value = 0, Original value = 1
# Mismatch at index 9002: Raster value = 0, Original value = 1
# Mismatch at index 9145: Raster value = 1, Original value = 0
# Mismatch at index 9146: Raster value = 1, Original value = 0
# Mismatch at index 9148: Raster value = 1, Original value = 0
# Mismatch at index 9255: Raster value = 1, Original value = 0
# Mismatch at index 9257: Raster value = 1, Original value = 0
# Mismatch at index 9258: Raster value = 1, Original value = 0
# Mismatch at index 9259: Raster value = 1, Original value = 0
# Mismatch at index 9260: Raster value = 1, Original value = 0
# Mismatch at index 9261: Raster value = 1, Original value = 0
# Mismatch at index 9262: Raster value = 1, Original value = 0
# Mismatch at index 9273: Raster value = 0, Original value = 1
# Mismatch at index 9275: Raster value = 0, Original value = 1
# Mismatch at index 9276: Raster value = 0, Original value = 1
# Mismatch at index 9422: Raster value = 1, Original value = 0
# Mismatch at index 9530: Raster value = 1, Original value = 0
# Mismatch at index 9532: Raster value = 1, Original value = 0
# Mismatch at index 9533: Raster value = 1, Original value = 0
# Mismatch at index 9534: Raster value = 1, Original value = 0
# Mismatch at index 9535: Raster value = 1, Original value = 0
# Mismatch at index 9536: Raster value = 1, Original value = 0
# Mismatch at index 9537: Raster value = 1, Original value = 0
# Mismatch at index 9550: Raster value = 0, Original value = 1
# Mismatch at index 9551: Raster value = 0, Original value = 1
# Mismatch at index 9552: Raster value = 0, Original value = 1
# Mismatch at index 9700: Raster value = 1, Original value = 0
# Mismatch at index 9703: Raster value = 1, Original value = 0
# Mismatch at index 9806: Raster value = 1, Original value = 0
# Mismatch at index 9809: Raster value = 1, Original value = 0
# Mismatch at index 9811: Raster value = 1, Original value = 0
# Mismatch at index 9812: Raster value = 1, Original value = 0
# Mismatch at index 9813: Raster value = 1, Original value = 0
# Mismatch at index 9814: Raster value = 1, Original value = 0
# Mismatch at index 9815: Raster value = 1, Original value = 0
# Mismatch at index 9816: Raster value = 1, Original value = 0
# Mismatch at index 9817: Raster value = 1, Original value = 0
# Mismatch at index 9819: Raster value = 1, Original value = 0
# Mismatch at index 9821: Raster value = 1, Original value = 0
# Mismatch at index 9827: Raster value = 1, Original value = 0
# Mismatch at index 9981: Raster value = 1, Original value = 0
# Mismatch at index 9984: Raster value = 1, Original value = 0
# Mismatch at index 10087: Raster value = 1, Original value = 0
# Mismatch at index 10089: Raster value = 1, Original value = 0
# Mismatch at index 10090: Raster value = 1, Original value = 0
# Mismatch at index 10091: Raster value = 1, Original value = 0
# Mismatch at index 10092: Raster value = 1, Original value = 0
# Mismatch at index 10093: Raster value = 1, Original value = 0
# Mismatch at index 10094: Raster value = 1, Original value = 0
# Mismatch at index 10096: Raster value = 1, Original value = 0
# Mismatch at index 10097: Raster value = 1, Original value = 0
# Mismatch at index 10099: Raster value = 1, Original value = 0
# Mismatch at index 10105: Raster value = 1, Original value = 0
# Mismatch at index 10263: Raster value = 1, Original value = 0
# Mismatch at index 10266: Raster value = 1, Original value = 0
# Mismatch at index 10369: Raster value = 1, Original value = 0
# Mismatch at index 10371: Raster value = 1, Original value = 0
# Mismatch at index 10372: Raster value = 1, Original value = 0
# Mismatch at index 10373: Raster value = 1, Original value = 0
# Mismatch at index 10374: Raster value = 1, Original value = 0
# Mismatch at index 10375: Raster value = 1, Original value = 0
# Mismatch at index 10379: Raster value = 1, Original value = 0
# Mismatch at index 10381: Raster value = 1, Original value = 0
# Mismatch at index 10548: Raster value = 1, Original value = 0
# Mismatch at index 10551: Raster value = 1, Original value = 0
# Mismatch at index 10656: Raster value = 1, Original value = 0
# Mismatch at index 10658: Raster value = 1, Original value = 0
# Mismatch at index 10659: Raster value = 1, Original value = 0
# Mismatch at index 10660: Raster value = 1, Original value = 0
# Mismatch at index 10661: Raster value = 1, Original value = 0
# Mismatch at index 10668: Raster value = 1, Original value = 0
# Mismatch at index 10840: Raster value = 1, Original value = 0
# Mismatch at index 10843: Raster value = 1, Original value = 0
# Mismatch at index 10946: Raster value = 1, Original value = 0
# Mismatch at index 10949: Raster value = 1, Original value = 0
# Mismatch at index 10951: Raster value = 1, Original value = 0
# Mismatch at index 10952: Raster value = 1, Original value = 0
# Mismatch at index 10953: Raster value = 1, Original value = 0
# Mismatch at index 10954: Raster value = 1, Original value = 0
# Mismatch at index 10961: Raster value = 1, Original value = 0
# Mismatch at index 11122: Raster value = 0, Original value = 1
# Mismatch at index 11135: Raster value = 1, Original value = 0
# Mismatch at index 11138: Raster value = 1, Original value = 0
# Mismatch at index 11159: Raster value = 0, Original value = 1
# Mismatch at index 11160: Raster value = 0, Original value = 1
# Mismatch at index 11242: Raster value = 1, Original value = 0
# Mismatch at index 11248: Raster value = 1, Original value = 0
# Mismatch at index 11250: Raster value = 1, Original value = 0
# Mismatch at index 11251: Raster value = 1, Original value = 0
# Mismatch at index 11252: Raster value = 1, Original value = 0
# Mismatch at index 11423: Raster value = 0, Original value = 1
# Mismatch at index 11436: Raster value = 1, Original value = 0
# Mismatch at index 11439: Raster value = 1, Original value = 0
# Mismatch at index 11440: Raster value = 1, Original value = 0
# Mismatch at index 11460: Raster value = 0, Original value = 1
# Mismatch at index 11856: Raster value = 1, Original value = 0
# Mismatch at index 11857: Raster value = 1, Original value = 0
# Mismatch at index 11885: Raster value = 0, Original value = 1
# Mismatch at index 11886: Raster value = 0, Original value = 1
# Mismatch at index 11887: Raster value = 0, Original value = 1
# Mismatch at index 11888: Raster value = 0, Original value = 1
# Mismatch at index 11889: Raster value = 0, Original value = 1
# Mismatch at index 12046: Raster value = 1, Original value = 0
# Mismatch at index 12049: Raster value = 1, Original value = 0
# Mismatch at index 12050: Raster value = 1, Original value = 0
# Mismatch at index 12163: Raster value = 1, Original value = 0
# Mismatch at index 12164: Raster value = 1, Original value = 0
# Mismatch at index 12190: Raster value = 0, Original value = 1
# Mismatch at index 12191: Raster value = 0, Original value = 1
# Mismatch at index 12192: Raster value = 0, Original value = 1
# Mismatch at index 12193: Raster value = 0, Original value = 1
# Mismatch at index 12194: Raster value = 0, Original value = 1
# Mismatch at index 12195: Raster value = 0, Original value = 1
# Mismatch at index 12196: Raster value = 0, Original value = 1
# Mismatch at index 12197: Raster value = 0, Original value = 1
# Mismatch at index 12198: Raster value = 0, Original value = 1
# Mismatch at index 12353: Raster value = 1, Original value = 0
# Mismatch at index 12356: Raster value = 1, Original value = 0
# Mismatch at index 12357: Raster value = 1, Original value = 0
# Mismatch at index 12378: Raster value = 0, Original value = 1
# Mismatch at index 12379: Raster value = 0, Original value = 1
# Mismatch at index 12471: Raster value = 1, Original value = 0
# Mismatch at index 12472: Raster value = 1, Original value = 0
# Mismatch at index 12473: Raster value = 1, Original value = 0
# Mismatch at index 12497: Raster value = 0, Original value = 1
# Mismatch at index 12498: Raster value = 0, Original value = 1
# Mismatch at index 12499: Raster value = 0, Original value = 1
# Mismatch at index 12500: Raster value = 0, Original value = 1
# Mismatch at index 12501: Raster value = 0, Original value = 1
# Mismatch at index 12502: Raster value = 0, Original value = 1
# Mismatch at index 12503: Raster value = 0, Original value = 1
# Mismatch at index 12504: Raster value = 0, Original value = 1
# Mismatch at index 12505: Raster value = 0, Original value = 1
# Mismatch at index 12506: Raster value = 0, Original value = 1
# Mismatch at index 12507: Raster value = 0, Original value = 1
# Mismatch at index 12562: Raster value = 1, Original value = 0
# Mismatch at index 12578: Raster value = 1, Original value = 0
# Mismatch at index 12579: Raster value = 1, Original value = 0
# Mismatch at index 12664: Raster value = 1, Original value = 0
# Mismatch at index 12665: Raster value = 1, Original value = 0
# Mismatch at index 12666: Raster value = 1, Original value = 0
# Mismatch at index 12686: Raster value = 0, Original value = 1
# Mismatch at index 12687: Raster value = 0, Original value = 1
# Mismatch at index 12688: Raster value = 0, Original value = 1
# Mismatch at index 12777: Raster value = 1, Original value = 0
# Mismatch at index 12778: Raster value = 1, Original value = 0
# Mismatch at index 12779: Raster value = 1, Original value = 0
# Mismatch at index 12800: Raster value = 0, Original value = 1
# Mismatch at index 12801: Raster value = 0, Original value = 1
# Mismatch at index 12802: Raster value = 0, Original value = 1
# Mismatch at index 12803: Raster value = 0, Original value = 1
# Mismatch at index 12804: Raster value = 0, Original value = 1
# Mismatch at index 12805: Raster value = 0, Original value = 1
# Mismatch at index 12806: Raster value = 0, Original value = 1
# Mismatch at index 12807: Raster value = 0, Original value = 1
# Mismatch at index 12808: Raster value = 0, Original value = 1
# Mismatch at index 12809: Raster value = 0, Original value = 1
# Mismatch at index 12810: Raster value = 0, Original value = 1
# Mismatch at index 12811: Raster value = 0, Original value = 1
# Mismatch at index 12812: Raster value = 0, Original value = 1
# Mismatch at index 12813: Raster value = 0, Original value = 1
# Mismatch at index 12814: Raster value = 0, Original value = 1
# Mismatch at index 12867: Raster value = 1, Original value = 0
# Mismatch at index 12971: Raster value = 1, Original value = 0
# Mismatch at index 12972: Raster value = 1, Original value = 0
# Mismatch at index 12974: Raster value = 1, Original value = 0
# Mismatch at index 12975: Raster value = 1, Original value = 0
# Mismatch at index 12992: Raster value = 0, Original value = 1
# Mismatch at index 13083: Raster value = 1, Original value = 0
# Mismatch at index 13084: Raster value = 1, Original value = 0
# Mismatch at index 13105: Raster value = 0, Original value = 1
# Mismatch at index 13106: Raster value = 0, Original value = 1
# Mismatch at index 13107: Raster value = 0, Original value = 1
# Mismatch at index 13108: Raster value = 0, Original value = 1
# Mismatch at index 13109: Raster value = 0, Original value = 1
# Mismatch at index 13110: Raster value = 0, Original value = 1
# Mismatch at index 13111: Raster value = 0, Original value = 1
# Mismatch at index 13112: Raster value = 0, Original value = 1
# Mismatch at index 13113: Raster value = 0, Original value = 1
# Mismatch at index 13114: Raster value = 0, Original value = 1
# Mismatch at index 13115: Raster value = 0, Original value = 1
# Mismatch at index 13116: Raster value = 0, Original value = 1
# Mismatch at index 13117: Raster value = 0, Original value = 1
# Mismatch at index 13118: Raster value = 0, Original value = 1
# Mismatch at index 13119: Raster value = 0, Original value = 1
# Mismatch at index 13172: Raster value = 1, Original value = 0
# Mismatch at index 13173: Raster value = 1, Original value = 0
# Mismatch at index 13277: Raster value = 1, Original value = 0
# Mismatch at index 13279: Raster value = 1, Original value = 0
# Mismatch at index 13280: Raster value = 1, Original value = 0
# Mismatch at index 13281: Raster value = 1, Original value = 0
# Mismatch at index 13295: Raster value = 0, Original value = 1
# Mismatch at index 13296: Raster value = 0, Original value = 1
# Mismatch at index 13297: Raster value = 0, Original value = 1
# Mismatch at index 13389: Raster value = 1, Original value = 0
# Mismatch at index 13390: Raster value = 1, Original value = 0
# Mismatch at index 13409: Raster value = 0, Original value = 1
# Mismatch at index 13410: Raster value = 0, Original value = 1
# Mismatch at index 13411: Raster value = 0, Original value = 1
# Mismatch at index 13412: Raster value = 0, Original value = 1
# Mismatch at index 13413: Raster value = 0, Original value = 1
# Mismatch at index 13414: Raster value = 0, Original value = 1
# Mismatch at index 13415: Raster value = 0, Original value = 1
# Mismatch at index 13416: Raster value = 0, Original value = 1
# Mismatch at index 13417: Raster value = 0, Original value = 1
# Mismatch at index 13418: Raster value = 0, Original value = 1
# Mismatch at index 13419: Raster value = 0, Original value = 1
# Mismatch at index 13420: Raster value = 0, Original value = 1
# Mismatch at index 13421: Raster value = 0, Original value = 1
# Mismatch at index 13422: Raster value = 0, Original value = 1
# Mismatch at index 13423: Raster value = 0, Original value = 1
# Mismatch at index 13424: Raster value = 0, Original value = 1
# Mismatch at index 13425: Raster value = 0, Original value = 1
# Mismatch at index 13478: Raster value = 1, Original value = 0
# Mismatch at index 13479: Raster value = 1, Original value = 0
# Mismatch at index 13583: Raster value = 1, Original value = 0
# Mismatch at index 13585: Raster value = 1, Original value = 0
# Mismatch at index 13586: Raster value = 1, Original value = 0
# Mismatch at index 13587: Raster value = 1, Original value = 0
# Mismatch at index 13602: Raster value = 0, Original value = 1
# Mismatch at index 13713: Raster value = 1, Original value = 0
# Mismatch at index 13714: Raster value = 1, Original value = 0
# Mismatch at index 13715: Raster value = 1, Original value = 0
# Mismatch at index 13730: Raster value = 0, Original value = 1
# Mismatch at index 13731: Raster value = 0, Original value = 1
# Mismatch at index 13732: Raster value = 0, Original value = 1
# Mismatch at index 13733: Raster value = 0, Original value = 1
# Mismatch at index 13734: Raster value = 0, Original value = 1
# Mismatch at index 13735: Raster value = 0, Original value = 1
# Mismatch at index 13736: Raster value = 0, Original value = 1
# Mismatch at index 13737: Raster value = 0, Original value = 1
# Mismatch at index 13738: Raster value = 0, Original value = 1
# Mismatch at index 13739: Raster value = 0, Original value = 1
# Mismatch at index 13740: Raster value = 0, Original value = 1
# Mismatch at index 13741: Raster value = 0, Original value = 1
# Mismatch at index 13742: Raster value = 0, Original value = 1
# Mismatch at index 13743: Raster value = 0, Original value = 1
# Mismatch at index 13744: Raster value = 0, Original value = 1
# Mismatch at index 13745: Raster value = 0, Original value = 1
# Mismatch at index 13746: Raster value = 0, Original value = 1
# Mismatch at index 13747: Raster value = 0, Original value = 1
# Mismatch at index 13748: Raster value = 0, Original value = 1
# Mismatch at index 13749: Raster value = 0, Original value = 1
# Mismatch at index 13802: Raster value = 1, Original value = 0
# Mismatch at index 13803: Raster value = 1, Original value = 0
# Mismatch at index 13909: Raster value = 1, Original value = 0
# Mismatch at index 13910: Raster value = 1, Original value = 0
# Mismatch at index 13911: Raster value = 1, Original value = 0
# Mismatch at index 14041: Raster value = 1, Original value = 0
# Mismatch at index 14042: Raster value = 1, Original value = 0
# Mismatch at index 14043: Raster value = 1, Original value = 0
# Mismatch at index 14057: Raster value = 0, Original value = 1
# Mismatch at index 14058: Raster value = 0, Original value = 1
# Mismatch at index 14059: Raster value = 0, Original value = 1
# Mismatch at index 14060: Raster value = 0, Original value = 1
# Mismatch at index 14061: Raster value = 0, Original value = 1
# Mismatch at index 14067: Raster value = 0, Original value = 1
# Mismatch at index 14068: Raster value = 0, Original value = 1
# Mismatch at index 14069: Raster value = 0, Original value = 1
# Mismatch at index 14070: Raster value = 0, Original value = 1
# Mismatch at index 14071: Raster value = 0, Original value = 1
# Mismatch at index 14072: Raster value = 0, Original value = 1
# Mismatch at index 14073: Raster value = 0, Original value = 1
# Mismatch at index 14074: Raster value = 0, Original value = 1
# Mismatch at index 14075: Raster value = 0, Original value = 1
# Mismatch at index 14076: Raster value = 0, Original value = 1
# Mismatch at index 14129: Raster value = 1, Original value = 0
# Mismatch at index 14130: Raster value = 1, Original value = 0
# Mismatch at index 14131: Raster value = 1, Original value = 0
# Mismatch at index 14239: Raster value = 1, Original value = 0
# Mismatch at index 14370: Raster value = 1, Original value = 0
# Mismatch at index 14371: Raster value = 1, Original value = 0
# Mismatch at index 14388: Raster value = 0, Original value = 1
# Mismatch at index 14389: Raster value = 0, Original value = 1
# Mismatch at index 14390: Raster value = 0, Original value = 1
# Mismatch at index 14396: Raster value = 0, Original value = 1
# Mismatch at index 14397: Raster value = 0, Original value = 1
# Mismatch at index 14398: Raster value = 0, Original value = 1
# Mismatch at index 14399: Raster value = 0, Original value = 1
# Mismatch at index 14400: Raster value = 0, Original value = 1
# Mismatch at index 14401: Raster value = 0, Original value = 1
# Mismatch at index 14402: Raster value = 0, Original value = 1
# Mismatch at index 14403: Raster value = 0, Original value = 1
# Mismatch at index 14404: Raster value = 0, Original value = 1
# Mismatch at index 14405: Raster value = 0, Original value = 1
# Mismatch at index 14458: Raster value = 1, Original value = 0
# Mismatch at index 14459: Raster value = 1, Original value = 0
# Mismatch at index 14460: Raster value = 1, Original value = 0
# Mismatch at index 14568: Raster value = 1, Original value = 0
# Mismatch at index 14584: Raster value = 0, Original value = 1
# Mismatch at index 14698: Raster value = 1, Original value = 0
# Mismatch at index 14699: Raster value = 1, Original value = 0
# Mismatch at index 14700: Raster value = 1, Original value = 0
# Mismatch at index 14718: Raster value = 0, Original value = 1
# Mismatch at index 14726: Raster value = 0, Original value = 1
# Mismatch at index 14727: Raster value = 0, Original value = 1
# Mismatch at index 14728: Raster value = 0, Original value = 1
# Mismatch at index 14729: Raster value = 0, Original value = 1
# Mismatch at index 14730: Raster value = 0, Original value = 1
# Mismatch at index 14734: Raster value = 0, Original value = 1
# Mismatch at index 14735: Raster value = 0, Original value = 1
# Mismatch at index 14745: Raster value = 0, Original value = 1
# Mismatch at index 14787: Raster value = 1, Original value = 0
# Mismatch at index 14788: Raster value = 1, Original value = 0
# Mismatch at index 14789: Raster value = 1, Original value = 0
# Mismatch at index 14897: Raster value = 1, Original value = 0
# Mismatch at index 14898: Raster value = 1, Original value = 0
# Mismatch at index 14913: Raster value = 0, Original value = 1
# Mismatch at index 14914: Raster value = 0, Original value = 1
# Mismatch at index 14915: Raster value = 0, Original value = 1
# Mismatch at index 15028: Raster value = 1, Original value = 0
# Mismatch at index 15029: Raster value = 1, Original value = 0
# Mismatch at index 15030: Raster value = 1, Original value = 0
# Mismatch at index 15057: Raster value = 0, Original value = 1
# Mismatch at index 15058: Raster value = 0, Original value = 1
# Mismatch at index 15059: Raster value = 0, Original value = 1
# Mismatch at index 15060: Raster value = 0, Original value = 1
# Mismatch at index 15064: Raster value = 0, Original value = 1
# Mismatch at index 15065: Raster value = 0, Original value = 1
# Mismatch at index 15113: Raster value = 1, Original value = 0
# Mismatch at index 15116: Raster value = 1, Original value = 0
# Mismatch at index 15117: Raster value = 1, Original value = 0
# Mismatch at index 15118: Raster value = 1, Original value = 0
# Mismatch at index 15119: Raster value = 1, Original value = 0
# Mismatch at index 15227: Raster value = 1, Original value = 0
# Mismatch at index 15228: Raster value = 1, Original value = 0
# Mismatch at index 15242: Raster value = 0, Original value = 1
# Mismatch at index 15243: Raster value = 0, Original value = 1
# Mismatch at index 15244: Raster value = 0, Original value = 1
# Mismatch at index 15245: Raster value = 0, Original value = 1
# Mismatch at index 15359: Raster value = 1, Original value = 0
# Mismatch at index 15361: Raster value = 1, Original value = 0
# Mismatch at index 15362: Raster value = 1, Original value = 0
# Mismatch at index 15363: Raster value = 1, Original value = 0
# Mismatch at index 15391: Raster value = 0, Original value = 1
# Mismatch at index 15392: Raster value = 0, Original value = 1
# Mismatch at index 15446: Raster value = 1, Original value = 0
# Mismatch at index 15449: Raster value = 1, Original value = 0
# Mismatch at index 15450: Raster value = 1, Original value = 0
# Mismatch at index 15451: Raster value = 1, Original value = 0
# Mismatch at index 15452: Raster value = 1, Original value = 0
# Mismatch at index 15537: Raster value = 0, Original value = 1
# Mismatch at index 15560: Raster value = 1, Original value = 0
# Mismatch at index 15561: Raster value = 1, Original value = 0
# Mismatch at index 15574: Raster value = 0, Original value = 1
# Mismatch at index 15575: Raster value = 0, Original value = 1
# Mismatch at index 15576: Raster value = 0, Original value = 1
# Mismatch at index 15577: Raster value = 0, Original value = 1
# Mismatch at index 15578: Raster value = 0, Original value = 1
# Mismatch at index 15695: Raster value = 1, Original value = 0
# Mismatch at index 15697: Raster value = 1, Original value = 0
# Mismatch at index 15698: Raster value = 1, Original value = 0
# Mismatch at index 15699: Raster value = 1, Original value = 0
# Mismatch at index 15727: Raster value = 0, Original value = 1
# Mismatch at index 15728: Raster value = 0, Original value = 1
# Mismatch at index 15738: Raster value = 0, Original value = 1
# Mismatch at index 15782: Raster value = 1, Original value = 0
# Mismatch at index 15785: Raster value = 1, Original value = 0
# Mismatch at index 15786: Raster value = 1, Original value = 0
# Mismatch at index 15787: Raster value = 1, Original value = 0
# Mismatch at index 15788: Raster value = 1, Original value = 0
# Mismatch at index 15790: Raster value = 1, Original value = 0
# Mismatch at index 15897: Raster value = 1, Original value = 0
# Mismatch at index 15910: Raster value = 0, Original value = 1
# Mismatch at index 15911: Raster value = 0, Original value = 1
# Mismatch at index 15912: Raster value = 0, Original value = 1
# Mismatch at index 15913: Raster value = 0, Original value = 1
# Mismatch at index 15914: Raster value = 0, Original value = 1
# Mismatch at index 15915: Raster value = 0, Original value = 1
# Mismatch at index 16029: Raster value = 1, Original value = 0
# Mismatch at index 16046: Raster value = 0, Original value = 1
# Mismatch at index 16064: Raster value = 0, Original value = 1
# Mismatch at index 16065: Raster value = 0, Original value = 1
# Mismatch at index 16066: Raster value = 0, Original value = 1
# Mismatch at index 16124: Raster value = 1, Original value = 0
# Mismatch at index 16125: Raster value = 1, Original value = 0
# Mismatch at index 16127: Raster value = 1, Original value = 0
# Mismatch at index 16210: Raster value = 0, Original value = 1
# Mismatch at index 16234: Raster value = 1, Original value = 0
# Mismatch at index 16247: Raster value = 0, Original value = 1
# Mismatch at index 16248: Raster value = 0, Original value = 1
# Mismatch at index 16249: Raster value = 0, Original value = 1
# Mismatch at index 16250: Raster value = 0, Original value = 1
# Mismatch at index 16251: Raster value = 0, Original value = 1
# Mismatch at index 16252: Raster value = 0, Original value = 1
# Mismatch at index 16404: Raster value = 0, Original value = 1
# Mismatch at index 16405: Raster value = 0, Original value = 1
# Mismatch at index 16406: Raster value = 0, Original value = 1
# Mismatch at index 16549: Raster value = 0, Original value = 1
# Mismatch at index 16550: Raster value = 0, Original value = 1
# Mismatch at index 16587: Raster value = 0, Original value = 1
# Mismatch at index 16588: Raster value = 0, Original value = 1
# Mismatch at index 16589: Raster value = 0, Original value = 1
# Mismatch at index 16590: Raster value = 0, Original value = 1
# Mismatch at index 16591: Raster value = 0, Original value = 1
# Mismatch at index 16746: Raster value = 0, Original value = 1
# Mismatch at index 16747: Raster value = 0, Original value = 1
# Mismatch at index 16748: Raster value = 0, Original value = 1
# Mismatch at index 16749: Raster value = 0, Original value = 1
# Mismatch at index 16892: Raster value = 0, Original value = 1
# Mismatch at index 16915: Raster value = 1, Original value = 0
# Mismatch at index 16916: Raster value = 1, Original value = 0
# Mismatch at index 16928: Raster value = 0, Original value = 1
# Mismatch at index 16929: Raster value = 0, Original value = 1
# Mismatch at index 16930: Raster value = 0, Original value = 1
# Mismatch at index 16931: Raster value = 0, Original value = 1
# Mismatch at index 17069: Raster value = 0, Original value = 1
# Mismatch at index 17070: Raster value = 0, Original value = 1
# Mismatch at index 17089: Raster value = 0, Original value = 1
# Mismatch at index 17090: Raster value = 0, Original value = 1
# Mismatch at index 17091: Raster value = 0, Original value = 1
# Mismatch at index 17092: Raster value = 0, Original value = 1
# Mismatch at index 17258: Raster value = 1, Original value = 0
# Mismatch at index 17259: Raster value = 1, Original value = 0
# Mismatch at index 17271: Raster value = 0, Original value = 1
# Mismatch at index 17272: Raster value = 0, Original value = 1
# Mismatch at index 17273: Raster value = 0, Original value = 1
# Mismatch at index 17274: Raster value = 0, Original value = 1
# Mismatch at index 17412: Raster value = 0, Original value = 1
# Mismatch at index 17413: Raster value = 0, Original value = 1
# Mismatch at index 17432: Raster value = 0, Original value = 1
# Mismatch at index 17433: Raster value = 0, Original value = 1
# Mismatch at index 17434: Raster value = 0, Original value = 1
# Mismatch at index 17435: Raster value = 0, Original value = 1
# Mismatch at index 17493: Raster value = 1, Original value = 0
# Mismatch at index 17562: Raster value = 1, Original value = 0
# Mismatch at index 17565: Raster value = 1, Original value = 0
# Mismatch at index 17601: Raster value = 1, Original value = 0
# Mismatch at index 17602: Raster value = 1, Original value = 0
# Mismatch at index 17757: Raster value = 0, Original value = 1
# Mismatch at index 17777: Raster value = 0, Original value = 1
# Mismatch at index 17778: Raster value = 0, Original value = 1
# Mismatch at index 17838: Raster value = 1, Original value = 0
# Mismatch at index 17907: Raster value = 1, Original value = 0
# Mismatch at index 17910: Raster value = 1, Original value = 0
# Mismatch at index 17946: Raster value = 1, Original value = 0
# Mismatch at index 17947: Raster value = 1, Original value = 0
# Mismatch at index 18081: Raster value = 1, Original value = 0
# Mismatch at index 18103: Raster value = 0, Original value = 1
# Mismatch at index 18157: Raster value = 1, Original value = 0
# Mismatch at index 18158: Raster value = 1, Original value = 0
# Mismatch at index 18159: Raster value = 1, Original value = 0
# Mismatch at index 18186: Raster value = 1, Original value = 0
# Mismatch at index 18293: Raster value = 1, Original value = 0
# Mismatch at index 18294: Raster value = 1, Original value = 0
# Mismatch at index 18429: Raster value = 1, Original value = 0
# Mismatch at index 18505: Raster value = 1, Original value = 0
# Mismatch at index 18506: Raster value = 1, Original value = 0
# Mismatch at index 18507: Raster value = 1, Original value = 0
# Mismatch at index 18534: Raster value = 1, Original value = 0
# Mismatch at index 18569: Raster value = 0, Original value = 1
# Mismatch at index 18570: Raster value = 0, Original value = 1
# Mismatch at index 18571: Raster value = 0, Original value = 1
# Mismatch at index 18572: Raster value = 0, Original value = 1
# Mismatch at index 18574: Raster value = 0, Original value = 1
# Mismatch at index 18575: Raster value = 0, Original value = 1
# Mismatch at index 18641: Raster value = 1, Original value = 0
# Mismatch at index 18642: Raster value = 1, Original value = 0
# Mismatch at index 18855: Raster value = 1, Original value = 0
# Mismatch at index 18856: Raster value = 1, Original value = 0
# Mismatch at index 18857: Raster value = 1, Original value = 0
# Mismatch at index 18883: Raster value = 1, Original value = 0
# Mismatch at index 18884: Raster value = 1, Original value = 0
# Mismatch at index 18918: Raster value = 0, Original value = 1
# Mismatch at index 18919: Raster value = 0, Original value = 1
# Mismatch at index 18920: Raster value = 0, Original value = 1
# Mismatch at index 18921: Raster value = 0, Original value = 1
# Mismatch at index 18922: Raster value = 0, Original value = 1
# Mismatch at index 18923: Raster value = 0, Original value = 1
# Mismatch at index 18924: Raster value = 0, Original value = 1
# Mismatch at index 18925: Raster value = 0, Original value = 1
# Mismatch at index 18926: Raster value = 0, Original value = 1
# ...
# Mismatch at index 111224: Raster value = 0, Original value = 1
# Mismatch at index 111225: Raster value = 0, Original value = 1
# Mismatch at index 111226: Raster value = 0, Original value = 1
# Mismatch at index 111227: Raster value = 0, Original value = 1
# Mismatch at index 111228: Raster value = 0, Original value = 1
# Mismatch at index 111229: Raster value = 0, Original value = 1
# Mismatch at index 111230: Raster value = 0, Original value = 1
# Mismatch at index 111236: Raster value = 1, Original value = 0
# Mismatch at index 111237: Raster value = 1, Original value = 0
# Mismatch at index 111238: Raster value = 1, Original value = 0
# Mismatch at index 111243: Raster value = 0, Original value = 1
# Mismatch at index 111244: Raster value = 0, Original value = 1
# Mismatch at index 111245: Raster value = 0, Original value = 1
# Mismatch at index 111316: Raster value = 0, Original value = 1
# Mismatch at index 111317: Raster value = 0, Original value = 1
# Mismatch at index 111375: Raster value = 0, Original value = 1
# Mismatch at index 111376: Raster value = 0, Original value = 1
# Mismatch at index 111436: Raster value = 1, Original value = 0
# Mismatch at index 111437: Raster value = 1, Original value = 0
# Mismatch at index 111438: Raster value = 1, Original value = 0
# Mismatch at index 111439: Raster value = 1, Original value = 0
# Mismatch at index 111440: Raster value = 0, Original value = 1
# Mismatch at index 111441: Raster value = 0, Original value = 1
# Mismatch at index 111442: Raster value = 0, Original value = 1
# Mismatch at index 111443: Raster value = 0, Original value = 1
# Mismatch at index 111444: Raster value = 0, Original value = 1
# Mismatch at index 111445: Raster value = 0, Original value = 1
# Mismatch at index 111446: Raster value = 0, Original value = 1
# Mismatch at index 111452: Raster value = 1, Original value = 0
# Mismatch at index 111453: Raster value = 1, Original value = 0
# Mismatch at index 111454: Raster value = 1, Original value = 0
# Mismatch at index 111457: Raster value = 0, Original value = 1
# Mismatch at index 111458: Raster value = 0, Original value = 1
# Mismatch at index 111459: Raster value = 0, Original value = 1
# Mismatch at index 111460: Raster value = 0, Original value = 1
# Mismatch at index 111461: Raster value = 0, Original value = 1
# Mismatch at index 111527: Raster value = 0, Original value = 1
# Mismatch at index 111528: Raster value = 0, Original value = 1
# Mismatch at index 111529: Raster value = 0, Original value = 1
# Mismatch at index 111648: Raster value = 1, Original value = 0
# Mismatch at index 111649: Raster value = 1, Original value = 0
# Mismatch at index 111651: Raster value = 0, Original value = 1
# Mismatch at index 111652: Raster value = 0, Original value = 1
# Mismatch at index 111653: Raster value = 0, Original value = 1
# Mismatch at index 111654: Raster value = 0, Original value = 1
# Mismatch at index 111655: Raster value = 0, Original value = 1
# Mismatch at index 111656: Raster value = 0, Original value = 1
# Mismatch at index 111664: Raster value = 0, Original value = 1
# Mismatch at index 111665: Raster value = 0, Original value = 1
# Mismatch at index 111666: Raster value = 0, Original value = 1
# Mismatch at index 111667: Raster value = 0, Original value = 1
# Mismatch at index 111668: Raster value = 0, Original value = 1
# Mismatch at index 111669: Raster value = 0, Original value = 1
# Mismatch at index 111670: Raster value = 0, Original value = 1
# Mismatch at index 111734: Raster value = 0, Original value = 1
# Mismatch at index 111735: Raster value = 0, Original value = 1
# Mismatch at index 111736: Raster value = 0, Original value = 1
# Mismatch at index 111855: Raster value = 0, Original value = 1
# Mismatch at index 111856: Raster value = 0, Original value = 1
# Mismatch at index 111857: Raster value = 0, Original value = 1
# Mismatch at index 111858: Raster value = 0, Original value = 1
# Mismatch at index 111859: Raster value = 0, Original value = 1
# Mismatch at index 111860: Raster value = 0, Original value = 1
# Mismatch at index 111861: Raster value = 1, Original value = 0
# Mismatch at index 111862: Raster value = 1, Original value = 0
# Mismatch at index 111863: Raster value = 1, Original value = 0
# Mismatch at index 111864: Raster value = 1, Original value = 0
# Mismatch at index 111865: Raster value = 1, Original value = 0
# Mismatch at index 111866: Raster value = 1, Original value = 0
# Mismatch at index 111867: Raster value = 0, Original value = 1
# Mismatch at index 111868: Raster value = 0, Original value = 1
# Mismatch at index 111869: Raster value = 0, Original value = 1
# Mismatch at index 111870: Raster value = 0, Original value = 1
# Mismatch at index 111871: Raster value = 0, Original value = 1
# Mismatch at index 111872: Raster value = 0, Original value = 1
# Mismatch at index 111873: Raster value = 0, Original value = 1
# Mismatch at index 112049: Raster value = 0, Original value = 1
# Mismatch at index 112050: Raster value = 0, Original value = 1
# Mismatch at index 112051: Raster value = 0, Original value = 1
# Mismatch at index 112052: Raster value = 0, Original value = 1
# Mismatch at index 112053: Raster value = 0, Original value = 1
# Mismatch at index 112054: Raster value = 0, Original value = 1
# Mismatch at index 112056: Raster value = 1, Original value = 0
# Mismatch at index 112057: Raster value = 1, Original value = 0
# Mismatch at index 112058: Raster value = 1, Original value = 0
# Mismatch at index 112059: Raster value = 1, Original value = 0
# Mismatch at index 112063: Raster value = 0, Original value = 1
# Mismatch at index 112242: Raster value = 0, Original value = 1
# Mismatch at index 112243: Raster value = 0, Original value = 1
# Mismatch at index 112244: Raster value = 0, Original value = 1
# Mismatch at index 112245: Raster value = 0, Original value = 1
# Mismatch at index 112246: Raster value = 0, Original value = 1
# Mismatch at index 112247: Raster value = 1, Original value = 0
# Mismatch at index 112248: Raster value = 1, Original value = 0
# Mismatch at index 112249: Raster value = 1, Original value = 0
# Mismatch at index 112250: Raster value = 1, Original value = 0
# Mismatch at index 112251: Raster value = 1, Original value = 0
# Mismatch at index 112430: Raster value = 1, Original value = 0
# Mismatch at index 112432: Raster value = 0, Original value = 1
# Mismatch at index 112433: Raster value = 0, Original value = 1
# Mismatch at index 112434: Raster value = 0, Original value = 1
# Mismatch at index 112435: Raster value = 0, Original value = 1
# Mismatch at index 112437: Raster value = 1, Original value = 0
# Mismatch at index 112438: Raster value = 1, Original value = 0
# Mismatch at index 112439: Raster value = 1, Original value = 0
# Mismatch at index 112440: Raster value = 1, Original value = 0
# Mismatch at index 112621: Raster value = 0, Original value = 1
# Mismatch at index 112622: Raster value = 0, Original value = 1
# Mismatch at index 112623: Raster value = 0, Original value = 1
# Mismatch at index 112624: Raster value = 0, Original value = 1
# Mismatch at index 112765: Raster value = 0, Original value = 1
# Mismatch at index 112766: Raster value = 0, Original value = 1
# Mismatch at index 112811: Raster value = 0, Original value = 1
# Mismatch at index 112812: Raster value = 0, Original value = 1
# Mismatch at index 112813: Raster value = 0, Original value = 1
# Mismatch at index 112951: Raster value = 0, Original value = 1
# Mismatch at index 112952: Raster value = 0, Original value = 1
# Mismatch at index 112953: Raster value = 0, Original value = 1
# Mismatch at index 112998: Raster value = 0, Original value = 1
# Mismatch at index 113006: Raster value = 0, Original value = 1
# Mismatch at index 113007: Raster value = 0, Original value = 1
# Mismatch at index 113138: Raster value = 0, Original value = 1
# Mismatch at index 113139: Raster value = 0, Original value = 1
# Mismatch at index 113140: Raster value = 0, Original value = 1
# Mismatch at index 113183: Raster value = 0, Original value = 1
# Mismatch at index 113193: Raster value = 0, Original value = 1
# Mismatch at index 113194: Raster value = 0, Original value = 1
# Mismatch at index 113376: Raster value = 0, Original value = 1
# Mismatch at index 113377: Raster value = 0, Original value = 1
# Mismatch at index 113527: Raster value = 1, Original value = 0
# Mismatch at index 113528: Raster value = 1, Original value = 0
# Mismatch at index 113600: Raster value = 0, Original value = 1
# Mismatch at index 113704: Raster value = 1, Original value = 0
# Mismatch at index 113705: Raster value = 1, Original value = 0
# Mismatch at index 113777: Raster value = 0, Original value = 1
# Mismatch at index 113836: Raster value = 0, Original value = 1
# Mismatch at index 113837: Raster value = 0, Original value = 1
# Mismatch at index 113881: Raster value = 1, Original value = 0
# Mismatch at index 113882: Raster value = 1, Original value = 0
# Mismatch at index 113895: Raster value = 1, Original value = 0
# Mismatch at index 114005: Raster value = 0, Original value = 1
# Mismatch at index 114006: Raster value = 0, Original value = 1
# Mismatch at index 114012: Raster value = 0, Original value = 1
# Mismatch at index 114071: Raster value = 1, Original value = 0
# Mismatch at index 114072: Raster value = 1, Original value = 0
# Mismatch at index 114073: Raster value = 1, Original value = 0
# Mismatch at index 114183: Raster value = 0, Original value = 1
# Mismatch at index 114248: Raster value = 1, Original value = 0
# Mismatch at index 114249: Raster value = 1, Original value = 0
# Mismatch at index 114250: Raster value = 1, Original value = 0
# Mismatch at index 114422: Raster value = 1, Original value = 0
# Mismatch at index 114423: Raster value = 1, Original value = 0
# Mismatch at index 114424: Raster value = 1, Original value = 0
# Mismatch at index 114425: Raster value = 1, Original value = 0
# Mismatch at index 114426: Raster value = 1, Original value = 0
# Mismatch at index 114525: Raster value = 0, Original value = 1
# Mismatch at index 114526: Raster value = 0, Original value = 1
# Mismatch at index 114527: Raster value = 0, Original value = 1
# Mismatch at index 114528: Raster value = 0, Original value = 1
# Mismatch at index 114587: Raster value = 1, Original value = 0
# Mismatch at index 114589: Raster value = 1, Original value = 0
# Mismatch at index 114590: Raster value = 1, Original value = 0
# Mismatch at index 114591: Raster value = 1, Original value = 0
# Mismatch at index 114592: Raster value = 1, Original value = 0
# Mismatch at index 114593: Raster value = 1, Original value = 0
# Mismatch at index 114594: Raster value = 1, Original value = 0
# Mismatch at index 114595: Raster value = 1, Original value = 0
# Mismatch at index 114596: Raster value = 1, Original value = 0
# Mismatch at index 114604: Raster value = 1, Original value = 0
# Mismatch at index 114696: Raster value = 0, Original value = 1
# Mismatch at index 114697: Raster value = 0, Original value = 1
# Mismatch at index 114698: Raster value = 0, Original value = 1
# Mismatch at index 114699: Raster value = 0, Original value = 1
# Mismatch at index 114711: Raster value = 0, Original value = 1
# Mismatch at index 114757: Raster value = 1, Original value = 0
# Mismatch at index 114759: Raster value = 1, Original value = 0
# Mismatch at index 114760: Raster value = 1, Original value = 0
# Mismatch at index 114761: Raster value = 1, Original value = 0
# Mismatch at index 114762: Raster value = 1, Original value = 0
# Mismatch at index 114763: Raster value = 1, Original value = 0
# Mismatch at index 114764: Raster value = 1, Original value = 0
# Mismatch at index 114765: Raster value = 1, Original value = 0
# Mismatch at index 114766: Raster value = 1, Original value = 0
# Mismatch at index 114774: Raster value = 1, Original value = 0
# Mismatch at index 114824: Raster value = 0, Original value = 1
# Mismatch at index 114825: Raster value = 0, Original value = 1
# Mismatch at index 114859: Raster value = 0, Original value = 1
# Mismatch at index 114860: Raster value = 0, Original value = 1
# Mismatch at index 114861: Raster value = 0, Original value = 1
# Mismatch at index 114890: Raster value = 0, Original value = 1
# Mismatch at index 114919: Raster value = 1, Original value = 0
# Mismatch at index 114921: Raster value = 1, Original value = 0
# Mismatch at index 114922: Raster value = 1, Original value = 0
# Mismatch at index 114923: Raster value = 1, Original value = 0
# Mismatch at index 114924: Raster value = 1, Original value = 0
# Mismatch at index 114925: Raster value = 1, Original value = 0
# Mismatch at index 114926: Raster value = 1, Original value = 0
# Mismatch at index 114927: Raster value = 1, Original value = 0
# Mismatch at index 114928: Raster value = 1, Original value = 0
# Mismatch at index 114936: Raster value = 1, Original value = 0
# Mismatch at index 114981: Raster value = 0, Original value = 1
# Mismatch at index 114982: Raster value = 0, Original value = 1
# Mismatch at index 115048: Raster value = 0, Original value = 1
# Mismatch at index 115083: Raster value = 1, Original value = 0
# Mismatch at index 115084: Raster value = 1, Original value = 0
# Mismatch at index 115095: Raster value = 1, Original value = 0
# Mismatch at index 115096: Raster value = 1, Original value = 0
# Mismatch at index 115135: Raster value = 0, Original value = 1
# Mismatch at index 115136: Raster value = 0, Original value = 1
# Mismatch at index 115165: Raster value = 0, Original value = 1
# Mismatch at index 115166: Raster value = 0, Original value = 1
# Mismatch at index 115283: Raster value = 0, Original value = 1
# Mismatch at index 115284: Raster value = 0, Original value = 1
# Mismatch at index 115314: Raster value = 0, Original value = 1
# Mismatch at index 115315: Raster value = 0, Original value = 1
# Mismatch at index 115488: Raster value = 0, Original value = 1
# Mismatch at index 115489: Raster value = 0, Original value = 1
# Mismatch at index 115610: Raster value = 0, Original value = 1
# Mismatch at index 115611: Raster value = 0, Original value = 1
# Mismatch at index 115633: Raster value = 0, Original value = 1
# Mismatch at index 115634: Raster value = 0, Original value = 1
# Mismatch at index 116290: Raster value = 0, Original value = 1
# Mismatch at index 116291: Raster value = 0, Original value = 1
# Mismatch at index 116385: Raster value = 1, Original value = 0
# Mismatch at index 116386: Raster value = 1, Original value = 0
# Mismatch at index 116422: Raster value = 0, Original value = 1
# Mismatch at index 116517: Raster value = 1, Original value = 0
# Mismatch at index 116518: Raster value = 1, Original value = 0
# Mismatch at index 116562: Raster value = 0, Original value = 1
# Mismatch at index 116563: Raster value = 0, Original value = 1
# Mismatch at index 116564: Raster value = 0, Original value = 1
# Mismatch at index 116697: Raster value = 0, Original value = 1
# Mismatch at index 117326: Raster value = 0, Original value = 1
# Mismatch at index 117359: Raster value = 0, Original value = 1
# Mismatch at index 117466: Raster value = 0, Original value = 1
# Mismatch at index 117467: Raster value = 0, Original value = 1
# Mismatch at index 117610: Raster value = 0, Original value = 1
# Mismatch at index 117672: Raster value = 0, Original value = 1
# Mismatch at index 117679: Raster value = 0, Original value = 1
# Mismatch at index 117711: Raster value = 0, Original value = 1
# Mismatch at index 117738: Raster value = 0, Original value = 1
# Mismatch at index 117748: Raster value = 0, Original value = 1
# Mismatch at index 117881: Raster value = 0, Original value = 1
# Mismatch at index 117942: Raster value = 0, Original value = 1
# Mismatch at index 117943: Raster value = 0, Original value = 1
# Mismatch at index 118032: Raster value = 0, Original value = 1
# Mismatch at index 118033: Raster value = 0, Original value = 1
# Mismatch at index 118034: Raster value = 0, Original value = 1
# Mismatch at index 118035: Raster value = 0, Original value = 1
# Mismatch at index 118036: Raster value = 0, Original value = 1
# Mismatch at index 118114: Raster value = 0, Original value = 1
# Mismatch at index 118115: Raster value = 0, Original value = 1
# Mismatch at index 118195: Raster value = 0, Original value = 1
